# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.

# %% [markdown]
# |name | student number|
# |----|----|
# |Jesper Krauth|2000416|

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)
library(dplyr)
library(readxl)

# %% [markdown]
# Now you have to read the the data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <- read.csv2("oecddata.csv")

# %% [markdown]
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd)
# Out:
#   X Country   Year Cost     LE
# 1 1 Australia 2005 2842.132 80.9
# 2 2 Australia 2006 3023.098 81.1
# 3 3 Australia 2007 3196.226 81.4
# 4 4 Australia 2008 3310.171 81.5
# 5 5 Australia 2009 3564.405 81.6
# 6 6 Australia 2010 3607.341 81.8

# %%
oecd
# Out:
#     X   Country        Year Cost      LE
# 1    1  Australia      2005 2842.132  80.9
# 2    2  Australia      2006 3023.098  81.1
# 3    3  Australia      2007 3196.226  81.4
# 4    4  Australia      2008 3310.171  81.5
# 5    5  Australia      2009 3564.405  81.6
# 6    6  Australia      2010 3607.341  81.8
# 7    7  Australia      2011 3794.087  82.0
# 8    8  Australia      2012 3807.682  82.1
# 9    9  Australia      2013 4176.853  82.2
# 10  10  Australia      2014 4206.852  82.4
# 11  11  Australia      2015 4420.436    NA
# 12  12  Austria        2005 3324.079  79.4
# 13  13  Austria        2006 3567.649  80.0
# 14  14  Austria        2007 3718.739  80.3
# 15  15  Austria        2008 3964.849  80.5
# 16  16  Austria        2009 4119.745  80.4
# 17  17  Austria        2010 4236.316  80.7
# 18  18  Austria        2011 4362.343  81.1
# 19  19  Austria        2012 4646.436  81.0
# 20  20  Austria        2013 4806.393  81.2
# 21  21  Austria        2014 4895.999  81.6
# ...

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- data.frame(oecd) %>%
        select(Country, Year, Cost, LE) %>%
        filter(Year == 2014)

# %%
graph1
# Out:
#    Country         Year Cost      LE
# 1  Australia       2014 4206.8516 82.4
# 2  Austria         2014 4895.9992 81.6
# 3  Belgium         2014 4522.0450 81.4
# 4  Canada          2014 4491.7648   NA
# 5  Chile           2014 1688.5233 79.0
# 6  Czech Republic  2014 2386.3385 78.9
# 7  Denmark         2014 4857.0285 80.8
# 8  Estonia         2014 1724.5100 77.2
# 9  Finland         2014 3870.4000 81.3
# 10 France          2014 4366.9864 82.8
# 11 Germany         2014 5119.2146 81.2
# 12 Greece          2014 2220.1065 81.5
# 13 Hungary         2014 1796.6034 75.9
# 14 Iceland         2014 3896.9251 82.9
# 15 Ireland         2014 5001.3220 81.4
# 16 Israel          2014 2547.4010 82.2
# 17 Italy           2014 3206.8286 83.2
# 18 Japan           2014 4152.3727 83.7
# 19 Korea           2014 2361.4400 82.2
# 20 Latvia          2014 1295.0128 74.3
# 21 Luxembourg      2014 6682.2370 82.3
# 22 Mexico          2014 1035.3389 74.8
# 23 Netherlands     2014 5276.6003 81.8
# ...

# %%
library(ggplot2)
library(ggrepel)

# %%
ggplot(graph1, aes(x=Cost, y=LE, label=Country))  + geom_point(shape=1) + geom_smooth(method=lm) + geom_text_repel(aes(label = Country), 
                  box.padding = unit(0.45, "lines")) + geom_smooth(method=lm)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_text_repel).”
# plot without title

# %% [markdown]
# The graph is now very messy, it is really crowded in some places and it is still hard to tell which dot belongs to which country. Because of this, we will replace the country names in the graph with country codes (for example, Latvia = LV). To do this, I created an Excel file with two columns, one with the name of the country and one with the corresponding country code. I have plotted this table below.

# %%
countrycodes <- read.csv2("countrycodes.csv") 
countrycodes
# Out:
#    Country         Code
# 1  Australia       AU
# 2  Austria         AT
# 3  Belgium         BE
# 4  Canada          CA
# 5  Chile           CL
# 6  Czech Republic  CZ
# 7  Denmark         DK
# 8  Estonia         EE
# 9  Finland         FI
# 10 France          FR
# 11 Germany         DE
# 12 Greece          GR
# 13 Hungary         HU
# 14 Iceland         IS
# 15 Ireland         IE
# 16 Israel          IL
# 17 Italy           IT
# 18 Japan           JP
# 19 Korea           KR
# 20 Latvia          LV
# 21 Luxembourg      LU
# 22 Mexico          MX
# 23 Netherlands     NL
# 24 New Zealand     NZ
# 25 Norway          NO
# 26 Poland          PL
# 27 Portugal        PT
# 28 Slovak Republic SK
# 29 Slovenia        SI
# 30 Spain           ES
# 31 Sweden          SE
# 32 Switzerland     CH
# 33 Turkey          TR
# 34 United Kingdom  GB
# 35 United States   US

# %%
graph1_total <- merge(graph1, countrycodes, by=c("Country"))
graph1_total
# Out:
#    Country         Year Cost      LE   Code
# 1  Australia       2014 4206.8516 82.4 AU
# 2  Austria         2014 4895.9992 81.6 AT
# 3  Belgium         2014 4522.0450 81.4 BE
# 4  Canada          2014 4491.7648   NA CA
# 5  Chile           2014 1688.5233 79.0 CL
# 6  Czech Republic  2014 2386.3385 78.9 CZ
# 7  Denmark         2014 4857.0285 80.8 DK
# 8  Estonia         2014 1724.5100 77.2 EE
# 9  Finland         2014 3870.4000 81.3 FI
# 10 France          2014 4366.9864 82.8 FR
# 11 Germany         2014 5119.2146 81.2 DE
# 12 Greece          2014 2220.1065 81.5 GR
# 13 Hungary         2014 1796.6034 75.9 HU
# 14 Iceland         2014 3896.9251 82.9 IS
# 15 Ireland         2014 5001.3220 81.4 IE
# 16 Israel          2014 2547.4010 82.2 IL
# 17 Italy           2014 3206.8286 83.2 IT
# 18 Japan           2014 4152.3727 83.7 JP
# 19 Korea           2014 2361.4400 82.2 KR
# 20 Latvia          2014 1295.0128 74.3 LV
# 21 Luxembourg      2014 6682.2370 82.3 LU
# ...

# %%
ggplot(graph1_total, aes(x=Cost, y=LE, label=Code))  + geom_point(shape=1) + geom_smooth(method=lm) + geom_text_repel(aes(label = Code), 
                  box.padding = unit(0.45, "lines")) + geom_smooth(method=lm)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_text_repel).”
# plot without title

# %% [markdown]
# Now, we have created a graph with countrycodes rather than with the full country name. In my personal opinion, this is more clear to observe and less messy to read

# %% [markdown]
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.

# %%
graph2 <- data.frame(oecd) %>%
        select(Country, Year, Cost) %>%
        filter(Country %in% c('United States', 'Latvia', 'Spain', 'Japan', 'Belgium'))

graph2
# Out:
#    Country       Year Cost
# 1  Belgium       2005 2985.8089
# 2  Belgium       2006 3136.9155
# 3  Belgium       2007 3286.2254
# 4  Belgium       2008 3542.3542
# 5  Belgium       2009 3804.7643
# 6  Belgium       2010 3901.9126
# 7  Belgium       2011 4132.3109
# 8  Belgium       2012 4286.4123
# 9  Belgium       2013 4485.4804
# 10 Belgium       2014 4522.0450
# 11 Belgium       2015 4611.2518
# 12 Japan         2005 2463.7249
# 13 Japan         2006 2580.1459
# 14 Japan         2007 2723.8322
# 15 Japan         2008 2852.8629
# 16 Japan         2009 2998.5676
# 17 Japan         2010 3204.9489
# 18 Japan         2011 3799.1178
# 19 Japan         2012 4016.7772
# 20 Japan         2013 4151.7546
# 21 Japan         2014 4152.3727
# 22 Japan         2015 4149.7650
# 23 Latvia        2005  828.3765
# 24 Latvia        2006  954.2433
# 25 Latvia        2007 1099.1831
# 26 Latvia        2008 1119.7091
# 27 Latvia        2009 1049.1766
# 28 Latvia        2010 1071.4247
# ...

# %%
graph2 <- filter(oecd, Country %in% c('United States', 'Latvia', 'Spain', 'Japan', 'Belgium'))%>%
select( Country, Year, Cost)
ggplot(graph2, aes(x = Year , y = Cost, col=Country)) + geom_line()
# Out:
# plot without title

# %% [markdown]
# I deliberately did not use country codes for this graph, as it is clear enough which line corresponds to which country and therefore does not need extra clarification

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- graph1 %>%
    na.omit(graph1) %>%
    mutate(Ratio = Cost / LE) %>%
    mutate(Score = min(Ratio) / Ratio) %>%
    arrange(Score)
eff
# Out:
#    Country         Year Cost      LE   Ratio     Score
# 1  United States   2014 9024.2064 78.8 114.52039 0.1108515
# 2  Switzerland     2014 6786.5657 83.3  81.47138 0.1558186
# 3  Luxembourg      2014 6682.2370 82.3  81.19365 0.1563516
# 4  Norway          2014 6080.9980 82.2  73.97808 0.1716016
# 5  Netherlands     2014 5276.6003 81.8  64.50612 0.1967992
# 6  Germany         2014 5119.2146 81.2  63.04451 0.2013618
# 7  Sweden          2014 5065.1613 82.3  61.54509 0.2062675
# 8  Ireland         2014 5001.3220 81.4  61.44130 0.2066160
# 9  Denmark         2014 4857.0285 80.8  60.11174 0.2111859
# 10 Austria         2014 4895.9992 81.6  59.99999 0.2115793
# 11 Belgium         2014 4522.0450 81.4  55.55338 0.2285145
# 12 France          2014 4366.9864 82.8  52.74138 0.2406982
# 13 Australia       2014 4206.8516 82.4  51.05402 0.2486533
# 14 Japan           2014 4152.3727 83.7  49.61019 0.2558901
# 15 United Kingdom  2014 3971.3940 81.4  48.78862 0.2601991
# ...

# %%
eff_graph <- ggplot(eff, aes(x = reorder(Country,Score), y = Score, fill= Country)) +
        geom_bar(stat = "identity") +
        theme(text = element_text(size=8), axis.text.x = element_text(angle = 50, hjust = 1))+
        scale_fill_manual(values = c(rep("blue",21),rep("red",1),rep("blue",12))) +
        guides(fill=FALSE) +
        xlab("Country") +
        ylab("Efficiency scores according to Jesper")

eff_graph
# Out:
# plot without title
